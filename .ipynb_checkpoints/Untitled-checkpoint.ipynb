# %%
import io
import os

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types
import matplotlib.pyplot as plt 
import cv2

# %%
def covert_bin_vec(like_li_vec):
    return  np.array([0 if a < 2 else 1 for a in like_li_vec])

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="google.json"
# # Instantiates a client
client = vision.ImageAnnotatorClient()

# The name of the image file to annotate
file_name = os.path.abspath('1.jpg')
#Emotions

emo = ['Angry', 'Surprised','Sad', 'Happy', "None"]
likelihood_name = ('UNKNOWN', 'VERY_UNLIKELY', 'UNLIKELY', 'POSSIBLE',
                    'LIKELY', 'VERY_LIKELY')

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

ok, buf = cv2.imencode(".jpeg",frame)
image = vision.types.Image(content=buf.tostring())

img = cv2.imread('1.jpg')
plt.imshow(img)
plt.show()
# Performs label detection on the image file
# response = client.label_detection(image=image)
# response_urface = client.face_detection(image=image)

labels = response.label_annotations

for face in response_urface.face_annotations:
    x = face.bounding_poly.vertices[0].x
    y = face.bounding_poly.vertices[0].y
    x2 = face.bounding_poly.vertices[2].x
    y2 = face.bounding_poly.vertices[2].y
    likelihood = vision.enums.Likelihood(face.surprise_likelihood)
    vertices = [f'({v.x},{v.y})' for v in face.bounding_poly.vertices]
#     landmard = [f'({v.x},{v.y})' for v in face.landmarks.vertices]
    cv2.rectangle(img, (x, y), (x2, y2), (255, 255, 255), 10)
    
    
    '''cv2.circle(image, center_coordinates, radius, color, thickness)'''
    for l in face.landmarks:
        cv2.circle(img,(int(l.position.x), int(l.position.y)),3,(255, 0, 255),4)
    angry = vision.enums.Likelihood(face.anger_likelihood)
    like_emo = [face.anger_likelihood , face.surprise_likelihood , face.sorrow_likelihood , face.joy_likelihood]
    emo_detected =  [likelihood_name[face.anger_likelihood],likelihood_name[face.surprise_likelihood], likelihood_name[face.sorrow_likelihood], likelihood_name[face.joy_likelihood]]
    bin_vec = covert_bin_vec(like_emo)
    print(bin_vec , np.argwhere(bin_vec ==1)[0,0] , emo[np.argwhere(bin_vec ==1)[0,0]])
    cv2.putText(img, emo[np.argwhere(bin_vec ==1)[0,0]], (x2-int((x2-x)/2), y2+150), cv2.FONT_HERSHEY_SIMPLEX, 5, (255, 255, 0), 16, cv2.LINE_AA)
    plt.imshow(img)
    plt.show()
    print("angry",angry, sad, emo_detected)
    print(f'Face surprised: {likelihood.name}')
    print(f'Face bounds: {",".join(vertices)}')

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a28265d3eb6> in <module>
#      19 image = types.Image(content=content)
#      20
# ---> 21 ok, buf = cv2.imencode(".jpeg",frame)
#      22 image = vision.types.Image(content=buf.tostring())
#      23
#
# NameError: name 'frame' is not defined

# %%
print(response_urface.face_annotations , len(response_urface.face_annotations))
print(vision.enums.Likelihood(response_urface.face_annotations[0].surprise_likelihood))
class_name = ["joy", "sad", "anger", "suprise"]
print(response_urface.face_annotations[0].landmarks)
for l in response_urface.face_annotations[0].landmarks:
    print(l.position.x , l.position.y)
# Out:
# [bounding_poly {
#   vertices {
#     x: 264
#     y: 63
#   }
#   vertices {
#     x: 905
#     y: 63
#   }
#   vertices {
#     x: 905
#     y: 808
#   }
#   vertices {
#     x: 264
#     y: 808
#   }
# }
# fd_bounding_poly {
#   vertices {
#     x: 366
#     y: 241
#   }
#   vertices {
#     x: 818
#     y: 241
#   }
#   vertices {
#     x: 818
#     y: 694
#   }
#   vertices {
#     x: 366
#     y: 694
#   }
# }
# landmarks {
#   type: LEFT_EYE
#   position {
#     x: 522.6505737304688
#     y: 387.0517272949219
#     z: 0.0043778130784630775
#   }
# }
# landmarks {
#   type: RIGHT_EYE
#   position {
#     x: 712.7088623046875
#     y: 400.3389892578125
#     z: 26.14132308959961
#   }
# }
# landmarks {
#   type: LEFT_OF_LEFT_EYEBROW
#   position {
#     x: 455.76397705078125
#     y: 339.717529296875
#     z: 10.504385948181152
#   }
# }
# landmarks {
#   type: RIGHT_OF_LEFT_EYEBROW
#   position {
#     x: 577.1549682617188
#     y: 344.607666015625
#     z: -29.11431312561035
#   }
# }
# landmarks {
#   type: LEFT_OF_RIGHT_EYEBROW
#   position {
#     x: 669.3612060546875
#     y: 351.3443603515625
#     z: -16.492334365844727
#   }
# }
# landmarks {
#   type: RIGHT_OF_RIGHT_EYEBROW
#   position {
#     x: 775.1489868164062
#     y: 367.226318359375
#     z: 54.28895950317383
#   }
# }
# landmarks {
#   type: MIDPOINT_BETWEEN_EYES
#   position {
#     x: 622.6697998046875
#     y: 382.8389892578125
#     z: -27.200775146484375
#   }
# }
# landmarks {
#   type: NOSE_TIP
#   position {
#     x: 619.7642211914062
#     y: 499.63922119140625
#     z: -87.39064025878906
#   }
# }
# landmarks {
#   type: UPPER_LIP
#   position {
#     x: 608.5637817382812
#     y: 576.2845458984375
#     z: -44.65431213378906
#   }
# }
# landmarks {
#   type: LOWER_LIP
#   position {
#     x: 605.5911254882812
#     y: 621.9761962890625
#     z: -33.892818450927734
#   }
# }
# landmarks {
#   type: MOUTH_LEFT
#   position {
#     x: 517.9793090820312
#     y: 607.504150390625
#     z: -4.180685997009277
#   }
# }
# landmarks {
#   type: MOUTH_RIGHT
#   position {
#     x: 679.4937133789062
#     y: 606.48681640625
#     z: 16.721641540527344
#   }
# }
# landmarks {
#   type: MOUTH_CENTER
#   position {
#     x: 606.5584106445312
#     y: 597.1322631835938
#     z: -31.66007423400879
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_RIGHT
#   position {
#     x: 659.544189453125
#     y: 518.4991455078125
#     z: -7.469249248504639
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_LEFT
#   position {
#     x: 562.5180053710938
#     y: 512.93212890625
#     z: -21.864213943481445
#   }
# }
# landmarks {
#   type: NOSE_BOTTOM_CENTER
#   position {
#     x: 613.8226318359375
#     y: 529.4417114257812
#     z: -44.148319244384766
#   }
# }
# landmarks {
#   type: LEFT_EYE_TOP_BOUNDARY
#   position {
#     x: 522.3165283203125
#     y: 374.11749267578125
#     z: -12.510167121887207
#   }
# }
# landmarks {
#   type: LEFT_EYE_RIGHT_CORNER
#   position {
#     x: 558.5269165039062
#     y: 390.1255187988281
#     z: 5.816697120666504
#   }
# }
# landmarks {
#   type: LEFT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 518.4800415039062
#     y: 399.3640441894531
#     z: -2.185584545135498
#   }
# }
# landmarks {
#   type: LEFT_EYE_LEFT_CORNER
#   position {
#     x: 479.23095703125
#     y: 385.955078125
#     z: 12.217287063598633
#   }
# }
# landmarks {
#   type: LEFT_EYE_PUPIL
#   position {
#     x: 517.1327514648438
#     y: 387.23980712890625
#     z: -5.088638782501221
#   }
# }
# landmarks {
#   type: RIGHT_EYE_TOP_BOUNDARY
#   position {
#     x: 712.921142578125
#     y: 388.1322021484375
#     z: 13.60645580291748
#   }
# }
# landmarks {
#   type: RIGHT_EYE_RIGHT_CORNER
#   position {
#     x: 745.90673828125
#     y: 405.488525390625
#     z: 48.72359848022461
#   }
# }
# landmarks {
#   type: RIGHT_EYE_BOTTOM_BOUNDARY
#   position {
#     x: 708.454833984375
#     y: 408.94500732421875
#     z: 23.766983032226562
#   }
# }
# landmarks {
#   type: RIGHT_EYE_LEFT_CORNER
#   position {
#     x: 669.9913330078125
#     y: 396.403564453125
#     z: 21.19196319580078
#   }
# }
# landmarks {
#   type: RIGHT_EYE_PUPIL
#   position {
#     x: 712.8267211914062
#     y: 401.4322204589844
#     z: 21.440244674682617
#   }
# }
# landmarks {
#   type: LEFT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 519.3226928710938
#     y: 317.72650146484375
#     z: -21.306304931640625
#   }
# }
# landmarks {
#   type: RIGHT_EYEBROW_UPPER_MIDPOINT
#   position {
#     x: 726.1842041015625
#     y: 333.0671691894531
#     z: 7.0066237449646
#   }
# }
# landmarks {
#   type: LEFT_EAR_TRAGION
#   position {
#     x: 358.4425048828125
#     y: 478.9744873046875
#     z: 216.1884307861328
#   }
# }
# landmarks {
#   type: RIGHT_EAR_TRAGION
#   position {
#     x: 792.666748046875
#     y: 511.6336975097656
#     z: 275.5965270996094
#   }
# }
# landmarks {
#   type: FOREHEAD_GLABELLA
#   position {
#     x: 624.4617309570312
#     y: 345.33349609375
#     z: -29.942243576049805
#   }
# }
# landmarks {
#   type: CHIN_GNATHION
#   position {
#     x: 593.7390747070312
#     y: 722.0513916015625
#     z: -9.196321487426758
#   }
# }
# landmarks {
#   type: CHIN_LEFT_GONION
#   position {
#     x: 382.0836181640625
#     y: 602.3150024414062
#     z: 136.41969299316406
#   }
# }
# landmarks {
#   type: CHIN_RIGHT_GONION
#   position {
#     x: 773.657958984375
#     y: 631.1690063476562
#     z: 190.02279663085938
#   }
# }
# roll_angle: 3.934840679168701
# pan_angle: 7.7812275886535645
# tilt_angle: 2.0843799114227295
# detection_confidence: 0.9983722567558289
# landmarking_confidence: 0.6169499754905701
# joy_likelihood: VERY_UNLIKELY
# sorrow_likelihood: POSSIBLE
# anger_likelihood: VERY_UNLIKELY
# surprise_likelihood: VERY_UNLIKELY
# under_exposed_likelihood: VERY_UNLIKELY
# blurred_likelihood: VERY_UNLIKELY
# headwear_likelihood: VERY_UNLIKELY
# ] 1
# Likelihood.VERY_UNLIKELY
# [type: LEFT_EYE
# position {
#   x: 522.6505737304688
#   y: 387.0517272949219
#   z: 0.0043778130784630775
# }
# , type: RIGHT_EYE
# position {
#   x: 712.7088623046875
#   y: 400.3389892578125
#   z: 26.14132308959961
# }
# , type: LEFT_OF_LEFT_EYEBROW
# position {
#   x: 455.76397705078125
#   y: 339.717529296875
#   z: 10.504385948181152
# }
# , type: RIGHT_OF_LEFT_EYEBROW
# position {
#   x: 577.1549682617188
#   y: 344.607666015625
#   z: -29.11431312561035
# }
# , type: LEFT_OF_RIGHT_EYEBROW
# position {
#   x: 669.3612060546875
#   y: 351.3443603515625
#   z: -16.492334365844727
# }
# , type: RIGHT_OF_RIGHT_EYEBROW
# position {
#   x: 775.1489868164062
#   y: 367.226318359375
#   z: 54.28895950317383
# }
# , type: MIDPOINT_BETWEEN_EYES
# position {
#   x: 622.6697998046875
#   y: 382.8389892578125
#   z: -27.200775146484375
# }
# , type: NOSE_TIP
# position {
#   x: 619.7642211914062
#   y: 499.63922119140625
#   z: -87.39064025878906
# }
# , type: UPPER_LIP
# position {
#   x: 608.5637817382812
#   y: 576.2845458984375
#   z: -44.65431213378906
# }
# , type: LOWER_LIP
# position {
#   x: 605.5911254882812
#   y: 621.9761962890625
#   z: -33.892818450927734
# }
# , type: MOUTH_LEFT
# position {
#   x: 517.9793090820312
#   y: 607.504150390625
#   z: -4.180685997009277
# }
# , type: MOUTH_RIGHT
# position {
#   x: 679.4937133789062
#   y: 606.48681640625
#   z: 16.721641540527344
# }
# , type: MOUTH_CENTER
# position {
#   x: 606.5584106445312
#   y: 597.1322631835938
#   z: -31.66007423400879
# }
# , type: NOSE_BOTTOM_RIGHT
# position {
#   x: 659.544189453125
#   y: 518.4991455078125
#   z: -7.469249248504639
# }
# , type: NOSE_BOTTOM_LEFT
# position {
#   x: 562.5180053710938
#   y: 512.93212890625
#   z: -21.864213943481445
# }
# , type: NOSE_BOTTOM_CENTER
# position {
#   x: 613.8226318359375
#   y: 529.4417114257812
#   z: -44.148319244384766
# }
# , type: LEFT_EYE_TOP_BOUNDARY
# position {
#   x: 522.3165283203125
#   y: 374.11749267578125
#   z: -12.510167121887207
# }
# , type: LEFT_EYE_RIGHT_CORNER
# position {
#   x: 558.5269165039062
#   y: 390.1255187988281
#   z: 5.816697120666504
# }
# , type: LEFT_EYE_BOTTOM_BOUNDARY
# position {
#   x: 518.4800415039062
#   y: 399.3640441894531
#   z: -2.185584545135498
# }
# , type: LEFT_EYE_LEFT_CORNER
# position {
#   x: 479.23095703125
#   y: 385.955078125
#   z: 12.217287063598633
# }
# , type: LEFT_EYE_PUPIL
# position {
#   x: 517.1327514648438
#   y: 387.23980712890625
#   z: -5.088638782501221
# }
# , type: RIGHT_EYE_TOP_BOUNDARY
# position {
#   x: 712.921142578125
#   y: 388.1322021484375
#   z: 13.60645580291748
# }
# , type: RIGHT_EYE_RIGHT_CORNER
# position {
#   x: 745.90673828125
#   y: 405.488525390625
#   z: 48.72359848022461
# }
# , type: RIGHT_EYE_BOTTOM_BOUNDARY
# position {
#   x: 708.454833984375
#   y: 408.94500732421875
#   z: 23.766983032226562
# }
# , type: RIGHT_EYE_LEFT_CORNER
# position {
#   x: 669.9913330078125
#   y: 396.403564453125
#   z: 21.19196319580078
# }
# , type: RIGHT_EYE_PUPIL
# position {
#   x: 712.8267211914062
#   y: 401.4322204589844
#   z: 21.440244674682617
# }
# , type: LEFT_EYEBROW_UPPER_MIDPOINT
# position {
#   x: 519.3226928710938
#   y: 317.72650146484375
#   z: -21.306304931640625
# }
# , type: RIGHT_EYEBROW_UPPER_MIDPOINT
# position {
#   x: 726.1842041015625
#   y: 333.0671691894531
#   z: 7.0066237449646
# }
# , type: LEFT_EAR_TRAGION
# position {
#   x: 358.4425048828125
#   y: 478.9744873046875
#   z: 216.1884307861328
# }
# , type: RIGHT_EAR_TRAGION
# position {
#   x: 792.666748046875
#   y: 511.6336975097656
#   z: 275.5965270996094
# }
# , type: FOREHEAD_GLABELLA
# position {
#   x: 624.4617309570312
#   y: 345.33349609375
#   z: -29.942243576049805
# }
# , type: CHIN_GNATHION
# position {
#   x: 593.7390747070312
#   y: 722.0513916015625
#   z: -9.196321487426758
# }
# , type: CHIN_LEFT_GONION
# position {
#   x: 382.0836181640625
#   y: 602.3150024414062
#   z: 136.41969299316406
# }
# , type: CHIN_RIGHT_GONION
# position {
#   x: 773.657958984375
#   y: 631.1690063476562
#   z: 190.02279663085938
# }
# ]
# 522.6505737304688 387.0517272949219
# 712.7088623046875 400.3389892578125
# 455.76397705078125 339.717529296875
# 577.1549682617188 344.607666015625
# 669.3612060546875 351.3443603515625
# 775.1489868164062 367.226318359375
# 622.6697998046875 382.8389892578125
# 619.7642211914062 499.63922119140625
# 608.5637817382812 576.2845458984375
# 605.5911254882812 621.9761962890625
# 517.9793090820312 607.504150390625
# 679.4937133789062 606.48681640625
# 606.5584106445312 597.1322631835938
# 659.544189453125 518.4991455078125
# 562.5180053710938 512.93212890625
# 613.8226318359375 529.4417114257812
# 522.3165283203125 374.11749267578125
# 558.5269165039062 390.1255187988281
# 518.4800415039062 399.3640441894531
# 479.23095703125 385.955078125
# 517.1327514648438 387.23980712890625
# 712.921142578125 388.1322021484375
# 745.90673828125 405.488525390625
# 708.454833984375 408.94500732421875
# 669.9913330078125 396.403564453125
# 712.8267211914062 401.4322204589844
# 519.3226928710938 317.72650146484375
# 726.1842041015625 333.0671691894531
# 358.4425048828125 478.9744873046875
# 792.666748046875 511.6336975097656
# 624.4617309570312 345.33349609375
# 593.7390747070312 722.0513916015625
# 382.0836181640625 602.3150024414062
# 773.657958984375 631.1690063476562

# %%
"""E:\Hackathon_Revolution\others-project\EmotionDetection\googleapiEMo"""

# %%
# prevents openCL usage and unnecessary logging messages
cv2.ocl.setUseOpenCL(False)

# dictionary which assigns each label an emotion (alphabetical order)


    # start the webcam feed
cap = cv2.VideoCapture(0)
i=0

while (True):
    # Find haar cascade to draw bounding box around face
    i+=1
    ret, frame = cap.read()
    if not ret:
        break
    ok, buf = cv2.imencode(".jpeg",frame)
    image = vision.types.Image(content=buf.tostring())
    client = vision.ImageAnnotatorClient()
    emo = ['Angry', 'Surprised','Sad', 'Happy', "None"]
    likelihood_name = ('UNKNOWN', 'VERY_UNLIKELY', 'UNLIKELY', 'POSSIBLE',
                    'LIKELY', 'VERY_LIKELY')
    response_urface = client.face_detection(image=image)
    
    for face in response_urface.face_annotations:
        x = face.bounding_poly.vertices[0].x
        y = face.bounding_poly.vertices[0].y
        x2 = face.bounding_poly.vertices[2].x
        y2 = face.bounding_poly.vertices[2].y
        likelihood = vision.enums.Likelihood(face.surprise_likelihood)
        vertices = [f'({v.x},{v.y})' for v in face.bounding_poly.vertices]
    #     landmard = [f'({v.x},{v.y})' for v in face.landmarks.vertices]
        cv2.rectangle(frame, (x, y), (x2, y2), (255, 255, 255), 4)


        '''cv2.circle(image, center_coordinates, radius, color, thickness)'''
        for l in face.landmarks:
            cv2.circle(frame,(int(l.position.x), int(l.position.y)),1,(255, 0, 255),4)
        angry = vision.enums.Likelihood(face.anger_likelihood)
        like_emo = [face.anger_likelihood , face.surprise_likelihood , face.sorrow_likelihood , face.joy_likelihood]
        emo_detected =  [likelihood_name[face.anger_likelihood],likelihood_name[face.surprise_likelihood], likelihood_name[face.sorrow_likelihood], likelihood_name[face.joy_likelihood]]
        bin_vec = covert_bin_vec(like_emo)
#         print(bin_vec)
        emotion_index = 4 if np.all(bin_vec == 0) else np.argwhere(bin_vec ==1)[0,0] 
        print(bin_vec , emotion_index , emo[emotion_index])
        cv2.putText(frame, emo[emotion_index], (x2-int((x2-x)/2), y2+20), cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 0), 1, cv2.LINE_AA)

#         print("angry",angry, sad, emo_detected)
#         print(f'Face surprised: {likelihood.name}')
#         print(f'Face bounds: {",".join(vertices)}')





    cv2.imshow('Video', cv2.resize(frame,(700,760),interpolation = cv2.INTER_CUBIC))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [1 0 0 0] 0 Angry
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 1 0] 2 Sad
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 1 0] 2 Sad
# [0 0 0 0] 4 None
# [0 0 1 0] 2 Sad
# [0 0 0 0] 4 None
# [0 0 1 0] 2 Sad
# [0 0 0 1] 3 Happy
# [0 0 1 0] 2 Sad
# [0 0 0 1] 3 Happy
# [0 0 1 0] 2 Sad
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 1 0 0] 1 Surprised
# [0 1 0 0] 1 Surprised
# [1 1 0 0] 0 Angry
# [0 1 0 0] 1 Surprised
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 1 0] 2 Sad
# [0 0 1 0] 2 Sad
# [0 0 1 0] 2 Sad
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 0] 4 None
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy
# [0 0 0 1] 3 Happy

# %%
cap.release()
cv2.destroyAllWindows()
